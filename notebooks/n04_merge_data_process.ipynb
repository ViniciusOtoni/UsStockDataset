# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
const = pd.read_csv("../data/d02_intermediate/const.csv")

# %%
dji =  pd.read_csv("../data/d02_intermediate/dji.csv")

# %%
dji  = dji.Close.to_frame().copy()

# %%
df = pd.concat([const, dji], axis=1)
df
# Out:
#                Company Exchange Symbol                Industry  Date_Added  \
# 0                   3M     NYSE    MMM            Conglomerate  1976-08-09
# 1     American Express     NYSE    AXP      Financial services  1982-08-30
# 2                Amgen   NASDAQ   AMGN       Biopharmaceutical  2020-08-31
# 3               Amazon   NASDAQ   AMZN               Retailing  2024-02-26
# 4                Apple   NASDAQ   AAPL  Information technology  2015-03-19
# ...                ...      ...    ...                     ...         ...
# 3328               NaN      NaN    NaN                     NaN         NaN
# 3329               NaN      NaN    NaN                     NaN         NaN
# 3330               NaN      NaN    NaN                     NaN         NaN
# 3331               NaN      NaN    NaN                     NaN         NaN
# 3332               NaN      NaN    NaN                     NaN         NaN
#
#              Close
# 0     12474.519531
# 1     12480.690430
# ...

# %%
df.rename(columns={"Close": "DJI"}, inplace=True)

# %%
df
# Out:
#                Company Exchange Symbol                Industry  Date_Added  \
# 0                   3M     NYSE    MMM            Conglomerate  1976-08-09
# 1     American Express     NYSE    AXP      Financial services  1982-08-30
# 2                Amgen   NASDAQ   AMGN       Biopharmaceutical  2020-08-31
# 3               Amazon   NASDAQ   AMZN               Retailing  2024-02-26
# 4                Apple   NASDAQ   AAPL  Information technology  2015-03-19
# ...                ...      ...    ...                     ...         ...
# 3328               NaN      NaN    NaN                     NaN         NaN
# 3329               NaN      NaN    NaN                     NaN         NaN
# 3330               NaN      NaN    NaN                     NaN         NaN
# 3331               NaN      NaN    NaN                     NaN         NaN
# 3332               NaN      NaN    NaN                     NaN         NaN
#
#                DJI
# 0     12474.519531
# 1     12480.690430
# ...

# %%
more_info = pd.read_csv("../data/d02_intermediate/const_prices.csv")
more_info
# Out:
#             Date       AAPL        AMGN       AMZN        AXP          BA  \
# 0     2007-01-03   2.992857   68.400002   1.935000  60.360001   89.169998
# 1     2007-01-04   3.059286   71.330002   1.945000  59.919998   89.529999
# 2     2007-01-05   3.037500   71.500000   1.918500  59.130001   89.150002
# 3     2007-01-08   3.052500   70.930000   1.875000  59.689999   88.940002
# 4     2007-01-09   3.306071   71.269997   1.889000  59.310001   88.000000
# ...          ...        ...         ...        ...        ...         ...
# 3328  2020-03-24  61.720001  202.339996  97.004997  84.050003  127.680000
# 3329  2020-03-25  61.380001  193.139999  94.292000  90.169998  158.729996
# 3330  2020-03-26  64.610001  198.490005  97.774498  93.290001  180.550003
# 3331  2020-03-27  61.935001  198.270004  95.004997  88.730003  162.000000
# 3332  2020-03-30  63.702499  208.479996  98.197502  90.269997  152.279999
#
#              CAT         CRM       CSCO        CVX  ...         MMM  \
# ...

# %%
df.plot(figsize=(20,12), fontsize=15, secondary_y="DJI")
plt.show()
